# %%
import pandas as pd

# Load Excel
file_path = '/Users/yoshifumihanada/Documents/SinotKampisos_materials/シノッカンピソㇱ8択問題ベース.xlsx'
df = pd.read_excel(file_path, sheet_name=1)
#df.drop(['Unnamed: 0'], axis=1, inplace=True)

# Show DataFrame
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 20 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0    ジャンル       9 non-null      object
#  1   難易度         9 non-null      object
#  2   【問題の文】日本語   9 non-null      object
#  3   【正】アイヌ語カナ   9 non-null      object
#  4   【正】日本語      9 non-null      object
#  5   【不1】アイヌ語カナ  9 non-null      object
#  6   【不1】日本語     9 non-null      object
#  7   【不2】アイヌ語カナ  9 non-null      object
#  8   【不2】日本語     9 non-null      object
#  9   【不3】アイヌ語カナ  9 non-null      object
#  10  【不3】日本語     9 non-null      object
#  11  【不4】アイヌ語カナ  9 non-null      object
#  12  【不4】日       9 non-null      object
#  13  【不5】アイヌ語カナ  9 non-null      object
#  14  【不5】日本語     9 non-null      object
#  15  【不6】アイヌ語カナ  9 non-null      object
#  16  【不6】日本語     9 non-null      object
#  17  【不7】アイヌ語カナ  9 non-null      object
#  18  【不7】日本語     9 non-null      object
# ...

# %%
# ilocがなぜか使えないので、列削除で対応

ain_quiz = df.drop(df.columns[[0, 1, 4, 6, 8, 10, 12, 14, 16, 18, 19]], axis=1)
ain_quiz.head()

output_path = './quiz_reordered.txt'

txt_buffer = []

for i in range(len(ain_quiz)):
    prefix = "'ACT03_10_{0:03d}".format(i)
    question = prefix + "_quiz': '" + ain_quiz.iloc[i,0] + "'," 

    txt_buffer.append(question)
    print(question)

    for j in range(1,9):
        op_desc = ain_quiz.iloc[i,j] if ain_quiz.iloc[i,j] != 'nan' else ''
        op = prefix + "_op{0}': '{1}',".format(j, op_desc)

        txt_buffer.append(op)
        print(op)

    txt_buffer.append('')
    print('='*20)

with open(output_path, 'w') as file:
    for line in txt_buffer:
        file.write(line + '\n')
# Out:
# 'ACT03_10_000_quiz': '「クジラ」はどのことば？',
# 'ACT03_10_000_op1': 'フンペ！',
# 'ACT03_10_000_op2': 'チェㇷ゚！',
# 'ACT03_10_000_op3': 'チェㇷ゚！',
# 'ACT03_10_000_op4': 'チェㇷ゚！',
# 'ACT03_10_000_op5': 'チェㇷ゚！',
# 'ACT03_10_000_op6': 'チェㇷ゚！',
# 'ACT03_10_000_op7': 'チェㇷ゚！',
# 'ACT03_10_000_op8': 'チェㇷ゚！',
# ...
# 'ACT03_10_001_quiz': '「こわい」はどのことば？',
# 'ACT03_10_001_op1': 'アシトマ',
# 'ACT03_10_001_op2': 'シヨキナ',
# 'ACT03_10_001_op3': 'シヨキナ',
# 'ACT03_10_001_op4': 'シヨキナ',
# 'ACT03_10_001_op5': 'シヨキナ',
# 'ACT03_10_001_op6': 'シヨキナ',
# 'ACT03_10_001_op7': 'シヨキナ',
# 'ACT03_10_001_op8': 'シヨキナ',
# ...
# 'ACT03_10_002_quiz': '「あぶない」はどのことば？',
# 'ACT03_10_002_op1': 'ヤイキㇷ゚テ',
# 'ACT03_10_002_op2': 'チェㇷ゚',
# 'ACT03_10_002_op3': 'チェㇷ゚',
# 'ACT03_10_002_op4': 'チェㇷ゚',
# 'ACT03_10_002_op5': 'チェㇷ゚',
# 'ACT03_10_002_op6': 'チェㇷ゚',
# 'ACT03_10_002_op7': 'チェㇷ゚',
# 'ACT03_10_002_op8': 'チェㇷ゚',
# ...
# 'ACT03_10_003_quiz': '「きる」はどのことば？',
# 'ACT03_10_003_op1': 'トゥイェ',
# 'ACT03_10_003_op2': 'キラ',
# 'ACT03_10_003_op3': 'キラ',
# 'ACT03_10_003_op4': 'キラ',
# ...
